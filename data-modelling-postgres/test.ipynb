'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)'),
#  (97, '2018-11-29 15:20:39.796', '26', 'free', None, None, '1046', 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (98, '2018-11-29 15:20:40.796', '26', 'free', None, None, '1046', 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (99, '2018-11-29 15:22:38.796', '49', 'paid', None, None, '1041', 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')]

# %%
# %sql SELECT * FROM users LIMIT 100;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 30 rows affected.
# [('73', 'Jacob', 'Klein', 'M', 'paid'),
#  ('50', 'Ava', 'Robinson', 'F', 'free'),
#  ('82', 'Avery', 'Martinez', 'F', 'paid'),
#  ('16', 'Rylan', 'George', 'M', 'paid'),
#  ('4', 'Alivia', 'Terrell', 'F', 'free'),
#  ('24', 'Layla', 'Griffin', 'F', 'paid'),
#  ('54', 'Kaleb', 'Cook', 'M', 'free'),
#  ('14', 'Theodore', 'Harris', 'M', 'free'),
#  ('98', 'Jordyn', 'Powell', 'F', 'free'),
#  ('78', 'Chloe', 'Roth', 'F', 'free'),
#  ('101', 'Jayden', 'Fox', 'M', 'free'),
#  ('10', 'Sylvie', 'Cruz', 'F', 'free'),
#  ('52', 'Theodore', 'Smith', 'M', 'free'),
#  ('53', 'Celeste', 'Williams', 'F', 'free'),
#  ('61', 'Samuel', 'Gonzalez', 'M', 'free'),
#  ('39', 'Walter', 'Frye', 'M', 'free'),
#  ('32', 'Lily', 'Burns', 'F', 'free'),
#  ('75', 'Joseph', 'Gutierrez', 'M', 'free'),
#  ('79', 'James', 'Martin', 'M', 'free'),
#  ('55', 'Martin', 'Johnson', 'M', 'free'),
#  ('', None, None, None, 'free'),
#  ('12', 'Austin', 'Rosales', 'M', 'free'),
#  ('26', 'Ryan', 'Smith', 'M', 'free'),
#  ('49', 'Chloe', 'Cuevas', 'F', 'paid'),
#  ('44', 'Aleena', 'Kirby', 'F', 'paid'),
#  ('9', 'Wyatt', 'Scott', 'M', 'free'),
#  ('22', 'Sean', 'Wilson', 'F', 'free'),
#  ('74', 'Braden', 'Parker', 'M', 'free'),
#  ('80', 'Tegan', 'Levine', 'F', 'paid'),
#  ('89', 'Kynnedi', 'Sanchez', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 149.86404)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('AR8IEZO1187B99055E', 'Marc Shaiman', '', 'NaN', 'NaN')]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('1970-01-01 00:25:43.449658', 0, '1', 1, 1, 1970, 3),
#  ('1970-01-01 00:25:43.449691', 0, '1', 1, 1, 1970, 3),
#  ('1970-01-01 00:25:43.449842', 0, '1', 1, 1, 1970, 3),
#  ('1970-01-01 00:25:43.449896', 0, '1', 1, 1, 1970, 3),
#  ('1970-01-01 00:25:43.450034', 0, '1', 1, 1, 1970, 3)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
